# %% [markdown]
# This is the beginning of my notebook for Assignment 4

# %% [markdown]
# I set up the environment manually in the OSC terminal and then sent it here. I installed conda, bioforge, jupyterlab, and the kernel. I'm sure i'll be adding a ton of packages as I continue the assignment. I then cloned my github and pushed everything (including the gitignore to my github repo. I did the gitignore manually on the command line, so it's not shown here in the notebook unfortunately.

# %% [markdown]
# Right now it also looks like there are a ton of dependencies in my environment, not sure what that's about

# %% [markdown]
# Okay I made the script executable as well so I can hopefully just load the environment directly

# %%
import pandas

# %%
data = pandas.read_csv('brain_size.csv', sep=';', na_values=".")
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# 13          14  Female   140  120  147   155.0    70.5     856472
# 14          15  Female    96  100   90   146.0    66.0     878897
# 15          16  Female    83   71   96   135.0    68.0     865363
# 16          17  Female   132  132  120   127.0    68.5     852244
# 17          18    Male   100   96  102   178.0    73.5     945088
# 18          19  Female   101  112   84   136.0    66.3     808020
# 19          20    Male    80   77   86   180.0    70.0     889083
# 20          21    Male    83   83   86     NaN     NaN     892420
# 21          22    Male    97  107   84   186.0    76.5     905940
# 22          23  Female   135  129  134   122.0    62.0     790619
# 23          24    Male   139  145  128   132.0    68.0     955003
# 24          25  Female    91   86  102   114.0    63.0     831772
# 25          26    Male   141  145  131   171.0    72.0     935494
# 26          27  Female    85   90   84   140.0    68.0     798612
# 27          28    Male   103   96  110   187.0    77.0    1062462
# 28          29  Female    77   83   72   106.0    63.0     793549
# 29          30  Female   130  126  124   159.0    66.5     866662
# 30          31  Female   133  126  132   127.0    62.5     857782
# 31          32    Male   144  145  137   191.0    67.0     949589
# 32          33    Male   103   96  110   192.0    75.5     997925
# 33          34    Male    90   96   86   181.0    69.0     879987
# 34          35  Female    83   90   81   143.0    66.5     834344
# 35          36  Female   133  129  128   153.0    66.5     948066
# 36          37    Male   140  150  124   144.0    70.5     949395
# 37          38  Female    88   86   94   139.0    64.5     893983
# 38          39    Male    81   90   74   148.0    74.0     930016
# 39          40    Male    89   91   89   179.0    75.5     935863

# %% [markdown]
# we made the table!

# %%
import numpy as np

t = np.linspace(-6, 6, 20)

sin_t = np.sin(t)

cos_t = np.cos(t)

# %%
pandas.DataFrame({'t': t, 'sin': sin_t, 'cos': cos_t})
# Out:
#            t       sin       cos
# 0  -6.000000  0.279415  0.960170
# 1  -5.368421  0.792419  0.609977
# 2  -4.736842  0.999701  0.024451
# 3  -4.105263  0.821291 -0.570509
# 4  -3.473684  0.326021 -0.945363
# 5  -2.842105 -0.295030 -0.955488
# 6  -2.210526 -0.802257 -0.596979
# 7  -1.578947 -0.999967 -0.008151
# 8  -0.947368 -0.811882  0.583822
# 9  -0.315789 -0.310567  0.950551
# 10  0.315789  0.310567  0.950551
# 11  0.947368  0.811882  0.583822
# 12  1.578947  0.999967 -0.008151
# 13  2.210526  0.802257 -0.596979
# 14  2.842105  0.295030 -0.955488
# 15  3.473684 -0.326021 -0.945363
# 16  4.105263 -0.821291 -0.570509
# 17  4.736842 -0.999701  0.024451
# 18  5.368421 -0.792419  0.609977
# 19  6.000000 -0.279415  0.960170

# %% [markdown]
# manipulating data

# %%
data.shape    # 40 rows and 8 columns


data.columns  # giving it columns   


print(data['Gender'])  # printing the named column   







# Simpler selector
data[data['Gender'] == 'Female']['VIQ'].mean()
# Out:
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7     Female
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20      Male
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26    Female
# 27      Male
# 28    Female
# 29    Female
# 30    Female
# 31      Male
# 32      Male
# 33      Male
# 34    Female
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39      Male
# Name: Gender, dtype: object
# np.float64(109.45)

# %%
groupby_gender = data.groupby('Gender')
for gender, value in groupby_gender['VIQ']:
    print((gender, value.mean()))
# Out:
# ('Female', np.float64(109.45))
# ('Male', np.float64(115.25))

# %%
groupby_gender.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4

# %% [markdown]
# now we have grouped the dataset by gender and made a new chart

# %%
print (value.mean())
# Out:
# 115.25

# %%
import numpy as np

# %%
from pandas.tools import plotting

plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from pandas.tools import plotting
#       3 plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
#
# ModuleNotFoundError: No module named 'pandas.tools'

# %% [markdown]
# okay so apparently this is an outdated pandas tool. i'll be using scatter matrix instead

# %%
from pandas.plotting import scatter_matrix

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
scatter_matrix(data[['Weight', 'Height', 'MRI_Count']], alpha=0.2, figsize=(6,6), diagonal= 'hist')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 scatter_matrix(data[['Weight', 'Height', 'MRI_Count']], alpha=0.2, figsize=(6,6), diagonal= 'hist')
#
# File ~/.conda/envs/stats-env/lib/python3.10/site-packages/pandas/plotting/_misc.py:219, in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     155 def scatter_matrix(
#     156     frame: DataFrame,
#     157     alpha: float = 0.5,
#    (...)
#     166     **kwargs,
#     167 ) -> np.ndarray:
#     168     """
#     169     Draw a matrix of scatter plots.
#     170
#    (...)
#     217               dtype=object)
#     218     """
# --> 219     plot_backend = _get_plot_backend("matplotlib")
#     220     return plot_backend.scatter_matrix(
#     221         frame=frame,
#     222         alpha=alpha,
#    (...)
#     231         **kwargs,
#     232     )
#
# File ~/.conda/envs/stats-env/lib/python3.10/site-packages/pandas/plotting/_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File ~/.conda/envs/stats-env/lib/python3.10/site-packages/pandas/plotting/_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
